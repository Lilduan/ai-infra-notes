# %% [markdown]
# # Euporie Demo
#
# This notebook is for terminal editing and execution testing.

# %%
message = 'hello from euporie 123'
print(message)
sum(range(5))
# Out:
# hello from euporie 123
# 10
